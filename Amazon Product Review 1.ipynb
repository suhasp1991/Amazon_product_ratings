# %%
        import pandas as pd
        from pandas_profiling import ProfileReport
        from datetime import datetime as dt
        import os
        import sys
        import seaborn as sns
        import numpy as np
        import matplotlib.pyplot as plt
        # %matplotlib inline

# %%
df = pd.read_csv('S:/Amazon Product Review/Data Set/7817_1.csv', low_memory=False)
df.head()
# Out:
#                      id       asins   brand                  categories  \
# 0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
#
#   colors             dateAdded           dateUpdated  \
# 0    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 1    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 2    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 3    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 4    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
#
#                   dimension  ean                         keys  ...  \
# 0  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# 1  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# ...

# %%
profile = ProfileReport(df, title='Amazon Product review_1', explorative=True)

# %%
profile.to_file("output_1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.describe()
# Out:
#                 ean  reviews.numHelpful  reviews.rating  reviews.userCity  \
# count  8.980000e+02          900.000000     1177.000000               0.0
# mean   8.443135e+11           83.584444        4.359388               NaN
# std    3.416444e+09          197.150238        1.021445               NaN
# min    8.416670e+11            0.000000        1.000000               NaN
# 25%    8.416670e+11            0.000000        4.000000               NaN
# 50%    8.416670e+11            0.000000        5.000000               NaN
# 75%    8.487190e+11           34.000000        5.000000               NaN
# max    8.487190e+11          997.000000        5.000000               NaN
#
#        reviews.userProvince  sizes           upc
# count                   0.0    0.0  8.980000e+02
# mean                    NaN    NaN  8.443135e+11
# std                     NaN    NaN  3.416444e+09
# min                     NaN    NaN  8.416670e+11
# 25%                     NaN    NaN  8.416670e+11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1597 non-null   object
#  1   asins                 1597 non-null   object
#  2   brand                 1597 non-null   object
#  3   categories            1597 non-null   object
#  4   colors                774 non-null    object
#  5   dateAdded             1597 non-null   object
#  6   dateUpdated           1597 non-null   object
#  7   dimension             565 non-null    object
#  8   ean                   898 non-null    float64
#  9   keys                  1597 non-null   object
#  10  manufacturer          965 non-null    object
#  11  manufacturerNumber    902 non-null    object
#  12  name                  1597 non-null   object
#  13  prices                1597 non-null   object
#  14  reviews.date          1217 non-null   object
# ...

# %%
df['dateAdded'] = pd.to_datetime(df['dateAdded'])
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df['dateAdded']
# Out:
# 0      2016-03-08 20:21:53+00:00
# 1      2016-03-08 20:21:53+00:00
# 2      2016-03-08 20:21:53+00:00
# 3      2016-03-08 20:21:53+00:00
# 4      2016-03-08 20:21:53+00:00
#                   ...
# 1592   2016-04-02 14:40:43+00:00
# 1593   2016-04-02 14:40:43+00:00
# 1594   2016-04-02 14:40:43+00:00
# 1595   2016-04-02 14:40:43+00:00
# 1596   2016-04-02 14:40:43+00:00
# Name: dateAdded, Length: 1597, dtype: datetime64[ns, UTC]

# %%
df.rename({"id":"ID", "dateAdded":"DATE", "asins":"PRODUCT ID","brand":"BRAND", "categories":"CATAGORY",
                    "reviews.rating":"RATING", "reviews.sourceURLs":"SOURCE", "reviews.text":"REVIEWS", "reviews.title":"REVIEWS TITLE"}, axis = 1, inplace = True)

# %%
df.drop(['colors','dateUpdated','ean','keys','manufacturer','manufacturerNumber','name','prices','reviews.date','reviews.doRecommend','reviews.numHelpful', 'reviews.username', 'sizes', 'upc','weight'], axis = 1, inplace=True)

# %%
df.drop(['dimension','reviews.userCity','reviews.userProvince'], axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1597 non-null   object
#  1   PRODUCT ID     1597 non-null   object
#  2   BRAND          1597 non-null   object
#  3   CATAGORY       1597 non-null   object
#  4   DATE           1597 non-null   datetime64[ns, UTC]
#  5   RATING         1177 non-null   float64
#  6   SOURCE         1597 non-null   object
#  7   REVIEWS        1597 non-null   object
#  8   REVIEWS TITLE  1580 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), object(7)
# memory usage: 112.4+ KB

# %%
df.to_csv('Amazon_Dataset_1', index=False)

# %%
df1 = pd.read_csv('Amazon_dataset.csv')

# %%
df1.head()
# Out:
#                      ID                       DATE           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  2018-10-25T16:36:31Z
#
#    PRODUCT ID   BRAND                                           CATAGORY  \
# 0  B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 1  B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 2  B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 3  B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 4  B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
#
#   PRIMARY CATAGORY  RATING                                             SOURCE  \
# ...

# %%
df1.drop(['dateUpdated'], axis = 1, inplace = True)

# %%
df1.head()
# Out:
#                      ID                       DATE  PRODUCT ID   BRAND  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  B00ZV9PXP2  Amazon
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  B00ZV9PXP2  Amazon
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  B00ZV9PXP2  Amazon
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  B00ZV9PXP2  Amazon
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03 16:56:05+00:00  B00ZV9PXP2  Amazon
#
#                                             CATAGORY PRIMARY CATAGORY  RATING  \
# 0  Computers,Electronics Features,Tablets,Electro...      Electronics       3
# 1  Computers,Electronics Features,Tablets,Electro...      Electronics       5
# 2  Computers,Electronics Features,Tablets,Electro...      Electronics       4
# 3  Computers,Electronics Features,Tablets,Electro...      Electronics       5
# 4  Computers,Electronics Features,Tablets,Electro...      Electronics       5
#
#                                               SOURCE  \
# ...

# %%
Complete_dataset =  [df, df1]

# %%
result = pd.concat(Complete_dataset)

# %%
result['DATE'] = pd.to_datetime(result['DATE'], utc=True)
print(result.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
result
# Out:
#                          ID  PRODUCT ID   BRAND  \
# 0      AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 1      AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 2      AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 3      AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 4      AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# ...                     ...         ...     ...
# 33327  AVqkIhxunnc1JgDc3kg_  B018T075DC  Amazon
# 33328  AVqkIhxunnc1JgDc3kg_  B018T075DC  Amazon
# 33329  AVqkIhxunnc1JgDc3kg_  B018T075DC  Amazon
# 33330  AVqkIhxunnc1JgDc3kg_  B018T075DC  Amazon
# 33331  AVqkIhxunnc1JgDc3kg_  B018T075DC  Amazon
#
#                                                 CATAGORY  \
# 0                             Amazon Devices,mazon.co.uk
# 1                             Amazon Devices,mazon.co.uk
# 2                             Amazon Devices,mazon.co.uk
# 3                             Amazon Devices,mazon.co.uk
# 4                             Amazon Devices,mazon.co.uk
# ...

# %%
result.to_csv('Dataset_Amazon', index = False)
